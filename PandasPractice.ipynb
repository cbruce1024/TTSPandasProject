# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/cbruc/OneDrive/Desktop/Pandas-Demo/data.csv")
#can also set index by adding , index_col='ResponseId'

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
pd.set_option('display.max_columns', 84)
pd.set_option('display.max_rows', 84)

# %%
schema_df = pd.read_csv('C:/Users/cbruc/OneDrive/Desktop/Pandas-Demo/survey_results_schema.csv', index_col = 'qname')

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
#Think of it like Dictionary [Python]: Keys are columns; Values are rows

# %%
df= pd.DataFrame(df)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df['Country']
# Out:
# 0                                 NaN
# 1            United States of America
# 2            United States of America
# 3            United States of America
# 4                         Philippines
#                      ...
# 89179                          Brazil
# 89180                         Romania
# 89181                          Israel
# 89182                     Switzerland
# 89183    Iran, Islamic Republic of...
# Name: Country, Length: 89184, dtype: object

# %%
df[['Country', 'Currency', 'Age' ]]
# Out:
#                             Country                   Currency  \
# 0                               NaN                        NaN
# 1          United States of America  USD\tUnited States dollar
# 2          United States of America  USD\tUnited States dollar
# 3          United States of America  USD\tUnited States dollar
# 4                       Philippines       PHP\tPhilippine peso
# ...                             ...                        ...
# 89179                        Brazil        BRL\tBrazilian real
# 89180                       Romania                        NaN
# 89181                        Israel                        NaN
# 89182                   Switzerland                        NaN
# 89183  Iran, Islamic Republic of...          IRR\tIranian rial
#
#                       Age
# 0         18-24 years old
# 1         25-34 years old
# 2         45-54 years old
# 3         25-34 years old
# 4         25-34 years old
# ...                   ...
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
# iloc allows us to access rows by INTEGER LOCATION
# If we think of loc and iloc as functions, rows are the first argument and columns are the second
#loc searches for labels

# %%
df.iloc[0:5, 3]
# Out:
# 0    18-24 years old
# 1    25-34 years old
# 2    45-54 years old
# 3    25-34 years old
# 4    25-34 years old
# Name: Age, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
#
#             Employment RemoteWork  \
# 0                  NaN        NaN
# 1  Employed, full-time     Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# ...

# %%
df.loc[0:2, 'Age']
# Out:
# 0    18-24 years old
# 1    25-34 years old
# 2    45-54 years old
# Name: Age, dtype: object

# %%
df.loc[0:3, ['Age', 'Country']]
# Out:
#                Age                   Country
# 0  18-24 years old                       NaN
# 1  25-34 years old  United States of America
# 2  45-54 years old  United States of America
# 3  25-34 years old  United States of America

# %%
df['LanguageHaveWorkedWith'].value_counts()
# Out:
# HTML/CSS;JavaScript;TypeScript                                                                        1487
# Python                                                                                                1132
# HTML/CSS;JavaScript                                                                                    735
# HTML/CSS;JavaScript;PHP;SQL                                                                            718
# C#                                                                                                     649
#                                                                                                       ...
# Bash/Shell (all shells);C;C#;Java;JavaScript;Perl;PHP;Python;SQL                                         1
# Assembly;C;JavaScript;MATLAB;SQL                                                                         1
# C#;Crystal                                                                                               1
# ...

# %%
df.loc[0:3, 'LanguageHaveWorkedWith': 'NEWCollabToolsWantToWorkWith']
########^last value is inclusive using loc
# Out:
#                               LanguageHaveWorkedWith  \
# 0                                                NaN
# 1                         HTML/CSS;JavaScript;Python
# 2                         Bash/Shell (all shells);Go
# 3  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
#
#                               LanguageWantToWorkWith DatabaseHaveWorkedWith  \
# 0                                                NaN                    NaN
# 1  Bash/Shell (all shells);C#;Dart;Elixir;GDScrip...               Supabase
# 2                                 Haskell;OCaml;Rust                    NaN
# 3  Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...       PostgreSQL;Redis
#
#                 DatabaseWantToWorkWith  \
# 0                                  NaN
# 1  Firebase Realtime Database;Supabase
# 2                                  NaN
# 3                     PostgreSQL;Redis
#
#                               PlatformHaveWorkedWith PlatformWantToWorkWith  \
# ...

# %%
df.set_index('ResponseId', inplace =True)
#changing index to equal ResponseID

# %%
df.index

# %%
schema_df.loc['Age']
# Out:
# qid                        QID127
# question      What is your age? *
# force_resp                   True
# type                           MC
# selector                     MAVR
# Name: Age, dtype: object

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
filt = (df['Country'] == 'United States of America')

# %%
filt
# Out:
# ResponseId
# 1        False
# 2         True
# 3         True
# 4         True
# 5        False
#          ...
# 89180    False
# 89181    False
# 89182    False
# 89183    False
# 89184    False
# Name: Country, Length: 89184, dtype: bool

# %%
df[filt]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# ...             ...                                                ...
# 89151       I agree  I used to be a developer by profession, but no...
# 89155       I agree                     I am a developer by profession
# 89157       I agree                     I am a developer by profession
# 89176       I agree                     I am a developer by profession
# 89179       I agree                     I am a developer by profession
#
#                         Age           Employment  \
# ResponseId
# ...

# %%
usa_salary = df.loc[filt, 'CompTotal']
#another way to complete the above

# %%
# countries = ['United States of America']
# filt= df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
# df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %%
# df['LanguageHaveWorkedWith']
